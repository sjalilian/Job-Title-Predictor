# %%
import pandas as pd
import string
import re
data=pd.read_csv('data_with_internal_info.csv', low_memory=False)
rows, columns = data.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 235277
# Number of columns: 60

# %%
columns_to_combine = ['Domain (en)','Specialisation (en)', 'Career ladder en','Level Title', 'HIERARCHIC MANAGEMENT',
'FUNCTIONAL MANAGEMENT', 'Required experience', 'Innovation','Is he/ she responsible for a certain budget/ figure?','Specify the budget amounts.','Diploma', 'Speciality', 'Row 4 - Column 1', 'Row 5 - Column 1',
    'Row 6 - Column 1', 'Row 7 - Column 1', 'Row 8 - Column 1',
    'Row 9 - Column 1', 'Internal Job Grade', 'Internal Job Grade','Department'
]
data["description"] = (
    data[columns_to_combine].fillna("").astype(str).agg(" | ".join, axis=1))

print(f"Rows before deduplication: {len(data)}")
data = data.drop_duplicates(subset="description", keep="first")
print(f"Rows after deduplication: {len(data)}")
# Out:
# Rows before deduplication: 235277
# Rows after deduplication: 69351

# %%
columns_to_combine = [
    "Domain (en)", "Specialisation (en)", "Career ladder en", "Level Title",
    "HIERARCHIC MANAGEMENT", "FUNCTIONAL MANAGEMENT", "Required experience",
    "Innovation", "Is he/ she responsible for a certain budget/ figure?",
    "Specify the budget amounts.", "Diploma", "Speciality",
    "Row 4 - Column 1", "Row 5 - Column 1", "Row 6 - Column 1",
    "Row 7 - Column 1", "Row 8 - Column 1", "Row 9 - Column 1",
 "Internal Job Grade",'Internal Job' ,      
    "Department"]

def _clean_token(s: str) -> str:
    table = str.maketrans("", "", string.punctuation)
    s = s.lower().translate(table)          
    s = re.sub(r"[^a-zA-Z0-9._\s]", "", s)  
    s = re.sub(r"\s+", " ", s).strip()
    return s

df = data.copy()                             
df[columns_to_combine] = df[columns_to_combine].fillna("").astype(str)

combined = df[columns_to_combine].agg(" ".join, axis=1)   # series of strings
df["description"] = combined.apply(_clean_token)
df["Reference Job"] = df["Reference Job"].astype(str).apply(_clean_token)
before = len(df)
df = df.drop_duplicates(subset="description", keep="first")
after = len(df)

print(f"Rows before dedup : {before}")
print(f"Rows after  dedup : {after}")
# Out:
# Rows before dedup : 69351
# Rows after  dedup : 69170

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np, torch
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,classification_report
from datasets import Dataset

X = df["description"]
y = df["Reference Job"]

label_encoder = LabelEncoder().fit(y)

X_train, X_test, y_train_str, y_test_str = train_test_split(X, y,test_size=0.40,random_state=42,stratify=y)

y_train = label_encoder.transform(y_train_str)
y_test  = label_encoder.transform(y_test_str)

print("Classes:", label_encoder.classes_)
print("Train shape:", X_train.shape, y_train.shape)
print("Test shape: ", X_test.shape, y_test.shape)
# Out:
# Classes: ['aankoper' 'account manager' 'administratief bediende' 'agile coach'
#  'allround technieker' 'analist developer' 'animator' 'apotheker adjunct'
#  'apotheker assistent' 'apotheker titularis' 'assistent filiaalleider'
#  'assistent laborant' 'assistent verkoopadministratieorderverwerking'
#  'audit manager' 'bediende aankoop' 'bediende boekhouding'
#  'bediende customer service 1ste lijn'
#  'bediende customer service 2de lijn' 'bediende distributie'
#  'bediende logistiek' 'bediende marketing' 'bediende personeelsdienst'
#  'bediende productieplanning'
#  'bediende verkoopadministratieorderverwerking' 'bediende voorraadbeheer'
#  'bedrijfsarts' 'bedrijfsverpleegkundige' 'beleidsmedewerker'
#  'bidcontracts negotiations manager' 'big data analist' 'big data manager'
#  'boekhouder' 'bouwadviseurconsultant' 'brand manager'
#  'business analistconsultant' 'business development manager'
#  'business intelligence consultant' 'business unit manager' 'calculator'
#  'category manager' 'change expert' 'chapter lead' 'chauffeur'
#  'clinical operationstrial manager' 'clinical research associate'
#  'constructie manager' 'consultant accounting' 'consultant audit'
#  'consultant corporate finance' 'consultant legal'
#  'consultant strategy transformation' 'consultant tax'
#  'continuous improvement manager' 'contract manager' 'controller'
#  'cordinator onderhoud' 'cordinator productie' 'cost accountant'
#  'credit controller' 'crm specialist' 'csirt engineer'
#  'data protection manager' 'data protection officer' 'data scientist'
#  'database administrator' 'developer' 'digital content specialist'
#  'digital marketing manager' 'digital marketing specialist'
#  'digital project manager' 'digital strategist' 'directeur aankoop'
#  'directeur engineering' 'directeur financin administratie'
#  'directeur human resources' 'directeur it' 'directeur kwaliteit'
#  'directeur logistiek supply chain' 'directeur marketing'
#  'directeur productie onderhoud' 'directeur research development'
#  'directeur sales' 'directeur services' 'directeur woonzorgcentrum'
#  'dispatcher' 'district manager' 'dossierbeheerder klantenadviseur'
#  'douane specialist' 'ecommerce project manager' 'ecommerce sales manager'
#  'ecommerce sales specialist' 'employer branding officer'
#  'engineering technicus' 'enterprise architect' 'ergotherapeut'
#  'events manager' 'events specialist' 'executive assistant' 'expediteur'
#  'experienced consultant accounting' 'experienced consultant audit'
#  'experienced consultant corporate finance' 'experienced consultant legal'
#  'experienced consultant strategy transformation'
#  'experienced consultant tax' 'experienced general consultant'
#  'expert supply chain' 'facilities assistent' 'facilities cordinator'
#  'facilities manager' 'fieldcoach onderhoud' 'fieldcoach productie'
#  'filiaalleider' 'financieel analist' 'financile auditor' 'fiscalist'
#  'fleet cordinator' 'functioneel analistconsultant' 'general consultant'
#  'grafisch vormgever' 'helpdesk pc support' 'hoofd compliance'
#  'hoofd juridische zaken' 'hoofdaankoper' 'hoofdboekhouder'
#  'hoofdmagazijnier' 'hoofdverpleegkundige' 'hulpboekhouder' 'hulpkok'
#  'human resources business partner' 'human resources consultant'
#  'human resources manager' 'human resources officer'
#  'industrieel ontwerper' 'information security officer'
#  'ingenieur kwaliteit' 'ingenieur onderhoud' 'ingenieur productie'
#  'ingenieur research' 'internal communication officer'
#  'international exportsales manager' 'interne auditor'
#  'interne preventieadviseur niveau i'
#  'interne preventieadviseur niveau ii' 'it manager' 'it operator'
#  'it risk manager' 'keukenhulp' 'key account manager' 'kinderverzorger'
#  'kinesitherapeut' 'kok' 'kwaliteitscontroleur' 'kwaliteitsmanager'
#  'labo manager' 'laborant' 'legal counseladvisor'
#  'lijn of procesoperator productie' 'maatschappelijk assistent'
#  'machineoperator productie' 'magazijnier' 'magazijnmedewerker'
#  'manager aankoop' 'manager advertising promotion'
#  'manager boekhouden financin' 'manager budget controle'
#  'manager compensation benefits' 'manager consulting accounting'
#  'manager consulting audit' 'manager consulting corporate finance'
#  'manager consulting general' 'manager consulting legal'
#  'manager consulting strategy transformation' 'manager consulting tax'
#  'manager credit collect' 'manager customer service' 'manager distributie'
#  'manager logistiek' 'manager marktanalysemarktonderzoek' 'manager milieu'
#  'manager onderhoud' 'manager personeelsadministratie'
#  'manager pr communicatie' 'manager productie' 'manager productieplanning'
#  'manager productontwikkeling' 'manager rekrutering selectie'
#  'manager services' 'manager supply chain' 'manager technical support'
#  'manager televerkoop' 'manager training development'
#  'manager veiligheid gezondheid'
#  'manager verkoopadministratieorderverwerking' 'manager voorraadbeheer'
#  'marketing manager' 'marketing specialist'
#  'medewerker postverwerkingarchivaris' 'medewerker services'
#  'medical affairs advisor' 'medical science liaison' 'medisch directeur'
#  'mergers acquisition specialist' 'milieucordinator niveau a'
#  'milieucordinator niveau b' 'netwerkmanager' 'office manager'
#  'onderhoudstechnicus' 'ontwerptekenaar' 'operations support manager'
#  'paralegal officer' 'payroll specialist' 'personal assistant'
#  'personeelsplanner' 'plant manager' 'pricing manager'
#  'pricing specialist' 'procesingenieur' 'process engineering manager'
#  'process improvement expert' 'product manager' 'product owner'
#  'productadviseur' 'productieplanner' 'program manager'
#  'project assistent' 'project customer advisor'
#  'project engineering manager' 'project management officer'
#  'projectingenieur bouw' 'projectingenieur project engineering'
#  'projectleider bim' 'projectleider bouw' 'projectleider kwaliteit'
#  'projectleider labo' 'projectleider process engineering'
#  'projectleider project engineering' 'projectleidermanager'
#  'projectmanager bouw' 'projectmanager it' 'projectmanagerleider rd'
#  'projectmedewerker' 'projectontwikkelaar bouw' 'psycholoog'
#  'receptionistetelefoniste' 'regio sales manager' 'reporting officer'
#  'research assistant' 'research development manager' 'research scientist'
#  'risico analist' 'risk manager' 'ruimtelijk planner' 'sales engineer'
#  'sales manager' 'sales promotormerchandiser' 'sap specialistconsultant'
#  'schoonmaker' 'scrum master' 'search engine optimisation specialist'
#  'security architect' 'security consultant' 'security manager'
#  'security specialist' 'senior research scientist'
#  'software development manager' 'software engineer' 'solution architect'
#  'specialist advertising promotion' 'specialist compensation benefits'
#  'specialist compliance' 'specialist distributie'
#  'specialist marktanalysemarktonderzoek' 'specialist pr communicatie'
#  'specialist productontwikkeling' 'specialist rekrutering selectie'
#  'specialist training development' 'specialist voorraadbeheer'
#  'stabiliteitsingenieur' 'stafmedewerker' 'support engineer 1ste lijn'
#  'support engineer 2de lijn' 'sustainability manager'
#  'systeemadministrator' 'systeemarchitect' 'systeemingenieur'
#  'tax manager' 'teamleader customer service' 'teamleader logistiek'
#  'teamleader services' 'teamleader technical support'
#  'teamleader televerkoop' 'technical architect' 'technical trainer'
#  'technical writer engineering' 'technical writer marketing'
#  'technician teamleader' 'technisch administratief bediende'
#  'technisch medewerker' 'tekenaar' 'telecom engineer' 'televerkoper'
#  'trade marketing manager' 'trade marketing specialist' 'treasurer'
#  'treasury manager' 'vastgoed prospector'
#  'verantwoordelijke industrile relaties' 'verpleegkundige bachelor'
#  'verpleegkundige gegradueerd' 'vertaler' 'vertegenwoordiger'
#  'warehouse manager' 'webmaster' 'wellbeing specialist' 'werfleider bouw'
#  'werkvoorbereider' 'winkelbediendekassierster' 'zorgcordinator thuiszorg'
#  'zorgkundige' 'zorgmanager']
# Train shape: (41502,) (41502,)
# Test shape:  (27668,) (27668,)

# %%
# Approach1: fine-tuned Bert model without data augmentation
from transformers import (RobertaTokenizerFast,
    RobertaForSequenceClassification,
    TrainingArguments,
    Trainer,
    set_seed)
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

tokenizer = RobertaTokenizerFast.from_pretrained("roberta-base")

def tok(batch):
    return tokenizer(batch["text"],
                     truncation=True,
                     padding="max_length",
                     max_length=512)
train_ds = Dataset.from_pandas(pd.DataFrame({"text": X_train, "label": y_train})).map(tok, batched=True, remove_columns=["text"])

test_ds = Dataset.from_pandas(pd.DataFrame({"text": X_test, "label": y_test})).map(tok, batched=True, remove_columns=["text"])

def evaluate_metrics(labels, preds, target_names=None, print_report=False):
    metrics = {
        "accuracy": accuracy_score(labels, preds),
        "macro_precision": precision_score(labels, preds, average="macro", zero_division=0),
        "macro_recall": recall_score(labels, preds, average="macro", zero_division=0),
        "macro_f1": f1_score(labels, preds, average="macro", zero_division=0),
        "weighted_precision": precision_score(labels, preds, average="weighted", zero_division=0),
        "weighted_recall": recall_score(labels, preds, average="weighted", zero_division=0),
        "weighted_f1": f1_score(labels, preds, average="weighted", zero_division=0),
    }
    if print_report and target_names is not None:
        print(classification_report(labels, preds, target_names=target_names, digits=3))
    return metrics

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    return evaluate_metrics(labels, preds)

# 5. Load model
model = RobertaForSequenceClassification.from_pretrained(
    "roberta-base",
    num_labels=len(label_encoder.classes_)
)

training_args = TrainingArguments(
    output_dir="./results",
    do_train=True,
    do_eval=True,
    num_train_epochs=2,
    learning_rate=1e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_steps=1000,
    save_steps=1000,
    fp16=True,
    seed=42,
)

set_seed(42)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    compute_metrics=compute_metrics
)


trainer.train()
eval_metrics = trainer.evaluate()
print("Trainer evaluation metrics:", eval_metrics)

pred_output = trainer.predict(test_ds)
logits = pred_output.predictions
labels = pred_output.label_ids
preds = np.argmax(logits, axis=-1)

print("\nDetailed classification report:")
metrics = evaluate_metrics(labels, preds, target_names=label_encoder.classes_, print_report=True)
print("Summary metrics:", metrics)
# Out:
# 2025-11-06 10:49:58.043350: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762426198.066388   66015 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762426198.073739   66015 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762426198.093108   66015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762426198.093131   66015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762426198.093133   66015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1762426198.093135   66015 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-06 10:49:58.098841: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Map:   0%|          | 0/41502 [00:00<?, ? examples/s]
# Map:   0%|          | 0/27668 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#     <div>
#
#       <progress value='10376' max='10376' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10376/10376 38:48, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>4.828600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.739400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.664600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.098000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.806900</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.592100</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.473300</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.394000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.361900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.344800</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer evaluation metrics: {'eval_loss': 0.2650763690471649, 'eval_accuracy': 0.9693147318201533, 'eval_macro_precision': 0.8216899181811984, 'eval_macro_recall': 0.8380105488380757, 'eval_macro_f1': 0.8235950429403124, 'eval_weighted_precision': 0.9525455304325414, 'eval_weighted_recall': 0.9693147318201533, 'eval_weighted_f1': 0.9585868220016227, 'eval_runtime': 197.2345, 'eval_samples_per_second': 140.28, 'eval_steps_per_second': 17.538, 'epoch': 2.0}
#
#                                      webmaster      0.722     1.000     0.839        26
#                           wellbeing specialist      1.000     1.000     1.000        16
#                                werfleider bouw      1.000     1.000     1.000        73
#                               werkvoorbereider      1.000     1.000     1.000       128
#                      winkelbediendekassierster      1.000     1.000     1.000       992
#                       zorgcordinator thuiszorg      0.000     0.000     0.000         4
#                                    zorgkundige      0.000     0.000     0.000        14
#                                    zorgmanager      0.000     0.000     0.000         4
#
#                                       accuracy                          0.969     27668
#                                      macro avg      0.822     0.838     0.824     27668
#                                   weighted avg      0.953     0.969     0.959     27668
#
# Summary metrics: {'accuracy': 0.9693147318201533, 'macro_precision': 0.8216899181811984, 'macro_recall': 0.8380105488380757, 'macro_f1': 0.8235950429403124, 'weighted_precision': 0.9525455304325414, 'weighted_recall': 0.9693147318201533, 'weighted_f1': 0.9585868220016227}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
#finding minor classes to enrich them
threshold = 10

ser = pd.Series(y_train_str)
counts = ser.value_counts()

minority_labels = counts[counts < threshold].index.tolist()

print("Labels with fewer than", threshold, "samples:")
for lbl in minority_labels:
    print(f"  • {lbl}: {counts[lbl]} samples")
# Out:
# Labels with fewer than 10 samples:
#   • consultant legal: 9 samples
#   • consultant audit: 8 samples
#   • stabiliteitsingenieur: 8 samples
#   • consultant corporate finance: 8 samples
#   • csirt engineer: 7 samples
#   • zorgcordinator thuiszorg: 7 samples
#   • ecommerce sales manager: 7 samples
#   • search engine optimisation specialist: 5 samples
#   • medical science liaison: 5 samples
#   • keukenhulp: 5 samples
#   • ecommerce project manager: 5 samples
#   • animator: 5 samples
#   • hulpkok: 5 samples
#   • zorgmanager: 5 samples
#   • manager televerkoop: 4 samples
#   • apotheker titularis: 4 samples
#   • kinesitherapeut: 3 samples
#   • medisch directeur: 3 samples
#   • kinderverzorger: 2 samples
#   • apotheker assistent: 2 samples
#   • directeur woonzorgcentrum: 2 samples
#   • apotheker adjunct: 2 samples
#   • mergers acquisition specialist: 2 samples

# %%
#Approach2: bert+ data augmentation with gemeni with a simple prompt

import google.generativeai as genai
import google.auth
KEY_FILE_PATH = 'cloudrun_secret.json'
try:
    credentials, project_id = google.auth.load_credentials_from_file(KEY_FILE_PATH)
    genai.configure(credentials=credentials)
except FileNotFoundError:
    print(f"Error: Key file '{KEY_FILE_PATH}' not found.")
except Exception as e:
    print(f"Error loading credentials: {e}")


generation_config = {
    "temperature": 0.7,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 150,
}

gen_model = genai.GenerativeModel(
    "gemini-2.0-flash",generation_config=generation_config)

# threshold = 10
label_counts = df["Reference Job"].value_counts()
minority_labels = label_counts[label_counts < threshold].index.tolist()

print(f"Found {len(minority_labels)} minority labels to augment.")

synthetic_rows = []
for lbl in minority_labels:
    prompt = (f"Write an approximately 80–100 word job description for the role titled “{lbl}”. "
        "Include key responsibilities, required qualifications, and typical experience.")

    try:
        resp = gen_model.generate_content(prompt, generation_config=generation_config)
        text_content = getattr(resp, "text", "").strip()

        if not text_content:
            retry_config = dict(generation_config)
            retry_config["temperature"] = 0.3
            retry_config["max_output_tokens"] = 120  # shorter safer response
            resp_retry = gen_model.generate_content(prompt, generation_config=retry_config)
            text_content = getattr(resp_retry, "text", "").strip()

        if text_content:
            synthetic_rows.append({
                "text": text_content,
                "Reference Job": lbl
            })
            print(f"Successfully generated data for: {lbl}")
        else:
            print(f" Still no output for '{lbl}' (model refused).")

    except Exception as e:
        print(f" Error for '{lbl}': {e}")


synthetic_df = pd.DataFrame(synthetic_rows)

train_df = pd.DataFrame({
    "text": X_train, 
    "Reference Job": y_train_str })

# Combine original training data with new synthetic data
if not synthetic_df.empty:
    augmented_train_df = pd.concat([train_df, synthetic_df], ignore_index=True)
    print(f"Augmented training data. New size: {len(augmented_train_df)} rows.")
else:
    augmented_train_df = train_df.copy()
    print("No synthetic data was generated. Using original training data.")

augmented_train_df.to_csv("augmented_train_df.csv", index=False)

augmented_train_df["label"] = label_encoder.transform(augmented_train_df["Reference Job"])


def tokenize_fn(batch):
    return tokenizer(batch["text"], truncation=True, padding="max_length", max_length=512)

train_ds = Dataset.from_pandas(augmented_train_df[["text", "label"]]).map(
    tokenize_fn,
    batched=True,
    remove_columns=["text"])

if 'test_ds' not in locals():
    print("Warning: 'test_ds' is not defined. Evaluation will fail.")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, preds, average="macro", zero_division=0
    )
    f1_weighted = precision_recall_fscore_support(
        labels, preds, average="weighted", zero_division=0
    )[2]
    
    return {
        "accuracy": accuracy_score(labels, preds),
        "precision_macro": precision,
        "recall_macro": recall,
        "f1_macro": f1,
        "f1_weighted": f1_weighted,
    }


model = RobertaForSequenceClassification.from_pretrained(
    "roberta-base",
    num_labels=len(label_encoder.classes_) 
)

training_args = TrainingArguments(
    output_dir="./aug_results",
    do_train=True,
    do_eval=True,
    save_strategy="epoch",
    num_train_epochs=2,
    learning_rate=1e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_steps=1000,
    fp16=True,
    seed=42,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    compute_metrics=compute_metrics)

trainer.train()

metrics = trainer.evaluate()
print(metrics)

preds_output = trainer.predict(test_ds)
preds = np.argmax(preds_output.predictions, axis=-1)
print(classification_report(preds_output.label_ids,preds,target_names=label_encoder.classes_, zero_division=0))
# Out:
# Found 16 minority labels to augment.
# Successfully generated data for: keukenhulp
# Successfully generated data for: animator
# Successfully generated data for: ecommerce project manager
# Successfully generated data for: search engine optimisation specialist
# Successfully generated data for: zorgmanager
# Successfully generated data for: hulpkok
# Successfully generated data for: medical science liaison
# Successfully generated data for: apotheker titularis
# Successfully generated data for: manager televerkoop
# Successfully generated data for: medisch directeur
# Successfully generated data for: kinesitherapeut
# Successfully generated data for: kinderverzorger
# Successfully generated data for: apotheker assistent
# Successfully generated data for: mergers acquisition specialist
# Successfully generated data for: apotheker adjunct
# Successfully generated data for: directeur woonzorgcentrum
# Augmented training data. New size: 41518 rows.
# Map:   0%|          | 0/41518 [00:00<?, ? examples/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='10380' max='10380' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10380/10380 37:11, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>4.886000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.745300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.666000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>1.092600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.768000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.602200</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.482800</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.407500</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.367500</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.350000</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.26731356978416443, 'eval_accuracy': 0.9671100187942749, 'eval_precision_macro': 0.8099542574409226, 'eval_recall_macro': 0.8337082891943695, 'eval_f1_macro': 0.8177453848245034, 'eval_f1_weighted': 0.955576158694075, 'eval_runtime': 197.3906, 'eval_samples_per_second': 140.169, 'eval_steps_per_second': 17.524, 'epoch': 2.0}
#                                                 precision    recall  f1-score   support
#
#                                       aankoper       1.00      1.00      1.00       191
#                                account manager       1.00      1.00      1.00       408
#                        administratief bediende       1.00      1.00      1.00       557
#                                    agile coach       1.00      0.91      0.95        23
#                            allround technieker       0.57      1.00      0.73        23
#                              analist developer       1.00      1.00      1.00       267
#                                       animator       0.00      0.00      0.00         4
#                              apotheker adjunct       0.00      0.00      0.00         1
#                            apotheker assistent       0.00      0.00      0.00         2
#                            apotheker titularis       1.00      0.67      0.80         3
#                        assistent filiaalleider       1.00      1.00      1.00       531
#                             assistent laborant       1.00      1.00      1.00        20
#  assistent verkoopadministratieorderverwerking       1.00      1.00      1.00       182
#                                  audit manager       1.00      1.00      1.00        28
#                               bediende aankoop       1.00      1.00      1.00       122
#                           bediende boekhouding       1.00      1.00      1.00       100
#            bediende customer service 1ste lijn       1.00      1.00      1.00       201
#             bediende customer service 2de lijn       1.00      1.00      1.00       149
#                           bediende distributie       0.65      1.00      0.79        50
#                             bediende logistiek       1.00      1.00      1.00       189
#                             bediende marketing       1.00      1.00      1.00       122
#                      bediende personeelsdienst       1.00      1.00      1.00       138
#                     bediende productieplanning       1.00      1.00      1.00        58
#   bediende verkoopadministratieorderverwerking       1.00      1.00      1.00        88
#                        bediende voorraadbeheer       1.00      1.00      1.00        44
#                                   bedrijfsarts       0.67      1.00      0.80         8
#                        bedrijfsverpleegkundige       1.00      1.00      1.00        14
#                              beleidsmedewerker       1.00      1.00      1.00        84
#              bidcontracts negotiations manager       1.00      1.00      1.00        34
#                               big data analist       0.65      0.86      0.74        98
#                               big data manager       1.00      1.00      1.00        43
#                                     boekhouder       1.00      1.00      1.00       241
#                         bouwadviseurconsultant       0.38      1.00      0.55        16
#                                  brand manager       1.00      1.00      1.00        46
#                     business analistconsultant       1.00      1.00      1.00       400
#                   business development manager       0.99      1.00      0.99       176
#               business intelligence consultant       0.75      0.48      0.59        89
#                          business unit manager       1.00      1.00      1.00       188
#                                     calculator       1.00      1.00      1.00        28
#                               category manager       1.00      1.00      1.00        70
#                                  change expert       0.00      0.00      0.00        21
#                                   chapter lead       1.00      1.00      1.00        50
#                                      chauffeur       0.00      0.00      0.00        27
#               clinical operationstrial manager       1.00      1.00      1.00        12
#                    clinical research associate       0.00      0.00      0.00         9
#                            constructie manager       1.00      0.67      0.80        18
#                          consultant accounting       0.39      1.00      0.56        17
#                               consultant audit       0.00      0.00      0.00         5
#                   consultant corporate finance       0.00      0.00      0.00         6
#                               consultant legal       0.00      0.00      0.00         6
#             consultant strategy transformation       1.00      1.00      1.00         8
#                                 consultant tax       0.00      0.00      0.00        11
#                 continuous improvement manager       1.00      1.00      1.00        52
#                               contract manager       1.00      1.00      1.00        45
#                                     controller       1.00      1.00      1.00       192
#                           cordinator onderhoud       1.00      1.00      1.00        95
#                           cordinator productie       1.00      1.00      1.00       168
#                                cost accountant       1.00      1.00      1.00        40
#                              credit controller       1.00      1.00      1.00        58
#                                 crm specialist       0.00      0.00      0.00        20
#                    manager productontwikkeling       1.00      1.00      1.00        32
#                   manager rekrutering selectie       1.00      1.00      1.00        49
#                               manager services       1.00      1.00      1.00       286
#                           manager supply chain       1.00      1.00      1.00        87
#                      manager technical support       1.00      1.00      1.00        37
#                            manager televerkoop       0.00      0.00      0.00         2
#                   manager training development       1.00      1.00      1.00        61
#                  manager veiligheid gezondheid       1.00      1.00      1.00        88
#    manager verkoopadministratieorderverwerking       1.00      1.00      1.00        55
#                         manager voorraadbeheer       1.00      1.00      1.00        29
#                              marketing manager       1.00      1.00      1.00       139
#                           marketing specialist       1.00      1.00      1.00       135
#            medewerker postverwerkingarchivaris       1.00      1.00      1.00        33
#                            medewerker services       1.00      1.00      1.00        89
#                        medical affairs advisor       0.40      1.00      0.57         8
#                        medical science liaison       0.00      0.00      0.00         3
#                              medisch directeur       0.00      0.00      0.00         2
#                 mergers acquisition specialist       0.00      0.00      0.00         1
#                      milieucordinator niveau a       0.79      1.00      0.88        33
#                      milieucordinator niveau b       0.00      0.00      0.00         9
#                                 netwerkmanager       1.00      1.00      1.00        38
#                                 office manager       1.00      1.00      1.00       114
#                            onderhoudstechnicus       1.00      1.00      1.00       173
#                                ontwerptekenaar       0.57      1.00      0.72        88
#                     operations support manager       1.00      1.00      1.00        76
#                              paralegal officer       1.00      1.00      1.00        64
#                             payroll specialist       1.00      1.00      1.00       140
#                             personal assistant       1.00      1.00      1.00       248
#                              personeelsplanner       1.00      1.00      1.00        50
#                                  plant manager       1.00      1.00      1.00        40
#                                pricing manager       1.00      1.00      1.00        16
#                             pricing specialist       1.00      1.00      1.00        30
#                                procesingenieur       1.00      1.00      1.00       159
#                    process engineering manager       1.00      1.00      1.00        56
#                     process improvement expert       0.72      1.00      0.83       151
#                                product manager       1.00      1.00      1.00       209
#                                  product owner       0.91      1.00      0.95       130
#                                productadviseur       1.00      1.00      1.00       610
#                               productieplanner       1.00      1.00      1.00       156
#                                program manager       1.00      1.00      1.00       132
#                              project assistent       1.00      1.00      1.00        46
#                       project customer advisor       0.00      0.00      0.00        26
#                    project engineering manager       1.00      1.00      1.00       160
#                     project management officer       1.00      1.00      1.00        43
#                          projectingenieur bouw       0.95      1.00      0.97        57
#           projectingenieur project engineering       1.00      1.00      1.00       344
#                              projectleider bim       0.91      1.00      0.95        20
#                             projectleider bouw       0.67      1.00      0.80        69
#                        projectleider kwaliteit       1.00      1.00      1.00        70
#                             projectleider labo       1.00      1.00      1.00        34
#              projectleider process engineering       1.00      0.96      0.98        28
#              projectleider project engineering       0.99      1.00      1.00       171
#                           projectleidermanager       1.00      1.00      1.00       457
#                            projectmanager bouw       1.00      1.00      1.00        33
#                              projectmanager it       1.00      1.00      1.00       329
#                        projectmanagerleider rd       1.00      1.00      1.00        78
#                              projectmedewerker       1.00      1.00      1.00       221
#                       projectontwikkelaar bouw       0.00      0.00      0.00        15
#                                     psycholoog       0.00      0.00      0.00        12
#                       receptionistetelefoniste       1.00      1.00      1.00       116
#                            regio sales manager       1.00      1.00      1.00       106
#                              reporting officer       1.00      1.00      1.00        95
#                             research assistant       1.00      1.00      1.00        32
#                              vertegenwoordiger       1.00      1.00      1.00       191
#                              warehouse manager       1.00      1.00      1.00        76
#                                      webmaster       0.72      1.00      0.84        26
#                           wellbeing specialist       0.00      0.00      0.00        16
#                                werfleider bouw       1.00      1.00      1.00        73
#                               werkvoorbereider       1.00      1.00      1.00       128
#                      winkelbediendekassierster       1.00      1.00      1.00       992
#                       zorgcordinator thuiszorg       0.00      0.00      0.00         4
#                                    zorgkundige       0.87      0.93      0.90        14
#                                    zorgmanager       0.00      0.00      0.00         4
#
#                                       accuracy                           0.97     27668
#                                      macro avg       0.81      0.83      0.82     27668
#                                   weighted avg       0.95      0.97      0.96     27668

# %%
# Approach3: bert+ data augmentation with gemeni with a CoT prompt
few_shot_examples = """
Below are a couple of examples of how to generate job description for a job title job title. Your task is to follow the same logic.
Example 1:
Job Title: 'Senior Software Engineer'

Step-by-step thinking:
- 

Generated Output:
Technology | Backend Development | Expert | Senior | No | Yes, mentoring junior developers | 5 | High – contributes to architecture | No | N/A | Bachelor's Degree | Computer Science | Skill: Java/Spring | Skill: Cloud Platforms (AWS/Azure) | Skill: CI/CD Pipelines | Process: Agile/Scrum | N/A | N/A | 12 | Senior Software Engineer | Engineering

---

Example 2:
Job Title: 'Marketing Manager'

Step-by-step thinking:
- Domain: Sales & Marketing
- Specialisation: Digital Campaigns
- Career level: Manager
- Level title: Manager
- Hierarchical Management: Yes, manages a team of 3
- Functional Management: Yes, leads campaign strategy
- Experience: 4 years
- Innovation: Medium – develops new campaign ideas
- Budget Responsibility: Yes
- Budget Details: 75,000 EUR
- Diploma: Master's Degree in Marketing
- Key Skills: Google Analytics, Salesforce Marketing Cloud, SEO/SEM, Content Marketing
- Internal Job Grade: 11
- Department: Marketing

Generated Output:
Sales & Marketing | Digital Campaign Management | Manager | Manager | Yes, manages a team of 3 | Yes | 4 | Medium – develops new campaign ideas | Yes | 75000 EUR | Master's Degree | Marketing or Business Administration | Tool: Google Analytics | Tool: Salesforce Marketing Cloud | Skill: SEO/SEM Strategy | Skill: Content Marketing | N/A | N/A | 11 | Marketing Manager | Marketing"""

threshold = 10
label_counts = df["Reference Job"].value_counts()
minority_labels = label_counts[label_counts < threshold].index.tolist()

# Generate synthetic samples
synthetic_rows = []
for lbl in minority_labels:
    need = threshold - label_counts[lbl]
    for _ in range(need):
#         prompt = ( f"Look at the examples in {few_shot_examples}. Now it's your turn.\n"
# f"Think step-by-step and then generate the structured string in the same format for '{lbl}':." )
        prompt = (f"{few_shot_examples}\n\n" "Now it's your turn.\n"
    f"Think step-by-step and then generate the structured string "
    f"in the same format for '{lbl}':")
        response = gen_model.generate_content(prompt)
        synthetic_rows.append({
            "text": response.text.strip(),
            "Reference Job": lbl
        })

synthetic_df = pd.DataFrame(synthetic_rows)

# Combine with original training data
train_df = pd.DataFrame({
    "text": X_train.values,
    "Reference Job": y_train_str.values
})
augmented_train_df = pd.concat([train_df, synthetic_df], ignore_index=True)
augmented_train_df.to_csv("augmented_train_few_shot.csv", index=False)

augmented_train_df["label"] = label_encoder.transform(augmented_train_df["Reference Job"])


train_ds = Dataset.from_pandas(augmented_train_df[["text", "label"]]).map(tokenize_fn, batched=True, remove_columns=["text"])

training_args = TrainingArguments(
    output_dir="./aug_results",
    do_train=True,
    do_eval=True,
    save_strategy="epoch",
    num_train_epochs=2,
    learning_rate=1e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_steps=1000,
    fp16=True,
    seed=42,)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    compute_metrics=compute_metrics,)
trainer.train()

metrics = trainer.evaluate()
print(metrics)

preds_output = trainer.predict(test_ds)
preds = np.argmax(preds_output.predictions, axis=-1)
print(classification_report(
    preds_output.label_ids,
    preds,
    target_names=label_encoder.classes_, 
    zero_division=0))
# Out:
# Map:   0%|          | 0/41561 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='10392' max='10392' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10392/10392 37:27, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>1.724200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.082400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.747200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.549500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.408300</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.312900</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.280000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.233200</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.223100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.225600</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 0.16728153824806213, 'eval_accuracy': 0.9734350151799913, 'eval_precision': 0.8474136371854734, 'eval_recall': 0.8636309196323914, 'eval_f1': 0.964379207597503, 'eval_runtime': 197.6059, 'eval_samples_per_second': 140.016, 'eval_steps_per_second': 17.505, 'epoch': 2.0}
#                                                 precision    recall  f1-score   support
#
#                                       aankoper       1.00      1.00      1.00       191
#                                account manager       1.00      1.00      1.00       408
#                        administratief bediende       1.00      1.00      1.00       557
#                                    agile coach       1.00      1.00      1.00        23
#                            allround technieker       0.53      1.00      0.70        23
#                              analist developer       1.00      1.00      1.00       267
#                                       animator       0.00      0.00      0.00         4
#                              apotheker adjunct       0.00      0.00      0.00         1
#                            apotheker assistent       0.00      0.00      0.00         2
#                            apotheker titularis       1.00      0.33      0.50         3
#                        assistent filiaalleider       1.00      1.00      1.00       531
#                             assistent laborant       1.00      1.00      1.00        20
#  assistent verkoopadministratieorderverwerking       1.00      1.00      1.00       182
#                                  audit manager       1.00      1.00      1.00        28
#                               bediende aankoop       1.00      1.00      1.00       122
#                           bediende boekhouding       1.00      1.00      1.00       100
#            bediende customer service 1ste lijn       1.00      1.00      1.00       201
#             bediende customer service 2de lijn       1.00      1.00      1.00       149
#                           bediende distributie       0.65      1.00      0.79        50
#                             bediende logistiek       1.00      1.00      1.00       189
#                             bediende marketing       1.00      1.00      1.00       122
#                      bediende personeelsdienst       1.00      1.00      1.00       138
#                     bediende productieplanning       1.00      1.00      1.00        58
#   bediende verkoopadministratieorderverwerking       1.00      1.00      1.00        88
#                        bediende voorraadbeheer       1.00      1.00      1.00        44
#                                   bedrijfsarts       1.00      1.00      1.00         8
#                        bedrijfsverpleegkundige       1.00      1.00      1.00        14
#                              beleidsmedewerker       1.00      1.00      1.00        84
#              bidcontracts negotiations manager       1.00      1.00      1.00        34
#                               big data analist       0.74      0.83      0.78        98
#                               big data manager       1.00      1.00      1.00        43
#                                     boekhouder       1.00      1.00      1.00       241
#                         bouwadviseurconsultant       0.37      1.00      0.54        16
#                                  brand manager       1.00      1.00      1.00        46
#                     business analistconsultant       1.00      1.00      1.00       400
#                   business development manager       1.00      1.00      1.00       176
#               business intelligence consultant       0.78      0.67      0.72        89
#                          business unit manager       1.00      1.00      1.00       188
#                                     calculator       1.00      1.00      1.00        28
#                               category manager       1.00      1.00      1.00        70
#                                  change expert       1.00      1.00      1.00        21
#                 experienced general consultant       1.00      1.00      1.00        18
#                            expert supply chain       1.00      1.00      1.00       110
#                           facilities assistent       1.00      1.00      1.00       101
#                          facilities cordinator       1.00      1.00      1.00        80
#                             facilities manager       1.00      1.00      1.00        69
#                           fieldcoach onderhoud       1.00      1.00      1.00       109
#                           fieldcoach productie       1.00      1.00      1.00       227
#                                  filiaalleider       1.00      1.00      1.00       705
#                             financieel analist       1.00      1.00      1.00       144
#                              financile auditor       1.00      1.00      1.00        21
#                                      fiscalist       1.00      1.00      1.00        32
#                               fleet cordinator       1.00      1.00      1.00        49
#                  functioneel analistconsultant       1.00      1.00      1.00       304
#                             general consultant       0.81      1.00      0.90        26
#                             grafisch vormgever       0.94      1.00      0.97        88
#                            helpdesk pc support       1.00      1.00      1.00       152
#                               hoofd compliance       1.00      1.00      1.00        47
#                         hoofd juridische zaken       1.00      1.00      1.00        58
#                                  hoofdaankoper       1.00      1.00      1.00        65
#                                hoofdboekhouder       1.00      1.00      1.00       129
#                               hoofdmagazijnier       1.00      1.00      1.00        96
#                           hoofdverpleegkundige       0.67      1.00      0.80        20
#                                 hulpboekhouder       1.00      1.00      1.00        99
#                                        hulpkok       0.00      0.00      0.00         3
#               human resources business partner       0.78      1.00      0.87       188
#                     human resources consultant       0.00      0.00      0.00        54
#                        human resources manager       1.00      1.00      1.00       123
#                        human resources officer       1.00      1.00      1.00       154
#                          industrieel ontwerper       1.00      1.00      1.00        50
#                   information security officer       1.00      1.00      1.00        32
#                            ingenieur kwaliteit       1.00      1.00      1.00       178
#                            ingenieur onderhoud       1.00      1.00      1.00        79
#                            ingenieur productie       1.00      1.00      1.00       127
#                             ingenieur research       1.00      1.00      1.00       151
#                 internal communication officer       1.00      1.00      1.00        45
#              international exportsales manager       1.00      1.00      1.00        28
#                                interne auditor       0.00      0.00      0.00        60
#             interne preventieadviseur niveau i       1.00      0.82      0.90       127
#            interne preventieadviseur niveau ii       0.71      1.00      0.83        55
#                                     it manager       1.00      1.00      1.00       169
#                                    it operator       1.00      1.00      1.00        42
#                                it risk manager       0.00      0.00      0.00        10
#                                     keukenhulp       0.00      0.00      0.00         4
#                            key account manager       1.00      1.00      1.00       164
#                                kinderverzorger       0.00      0.00      0.00         2
#                                kinesitherapeut       0.00      0.00      0.00         2
#                                            kok       1.00      1.00      1.00        17
#                           kwaliteitscontroleur       1.00      1.00      1.00       137
#                              kwaliteitsmanager       1.00      1.00      1.00       119
#                                   labo manager       1.00      1.00      1.00        20
#                                       laborant       1.00      1.00      1.00       111
#                           legal counseladvisor       1.00      1.00      1.00       161
#               lijn of procesoperator productie       0.72      1.00      0.84       116
#                      maatschappelijk assistent       0.84      1.00      0.91        63
#                      machineoperator productie       0.00      0.00      0.00        45
#                                    magazijnier       1.00      1.00      1.00       116
#                             magazijnmedewerker       1.00      1.00      1.00        61
#                                manager aankoop       0.87      1.00      0.93       116
#                  manager advertising promotion       0.00      0.00      0.00        18
#                    manager boekhouden financin       1.00      1.00      1.00       127
#                        manager budget controle       1.00      1.00      1.00        73
#                  manager compensation benefits       1.00      1.00      1.00        37
#                  manager consulting accounting       1.00      1.00      1.00        13
#                       manager consulting audit       1.00      1.00      1.00        10
#           manager consulting corporate finance       1.00      1.00      1.00         9
#                     manager consulting general       1.00      1.00      1.00        14
#                       manager consulting legal       1.00      1.00      1.00         7
#     manager consulting strategy transformation       1.00      1.00      1.00        12
#                         manager consulting tax       1.00      1.00      1.00        12
#                         manager credit collect       1.00      1.00      1.00        20
#                       manager customer service       1.00      1.00      1.00       100
#                            manager distributie       1.00      1.00      1.00        54
#                              manager logistiek       1.00      1.00      1.00        76
#             manager marktanalysemarktonderzoek       1.00      1.00      1.00        19
#                                 manager milieu       1.00      1.00      1.00        18
#                              manager onderhoud       1.00      1.00      1.00        65
#                manager personeelsadministratie       1.00      1.00      1.00        44
#                        manager pr communicatie       0.84      1.00      0.91        94
#                              manager productie       1.00      1.00      1.00       124
#                      manager productieplanning       1.00      1.00      1.00        39
#                    manager productontwikkeling       1.00      1.00      1.00        32
#                   manager rekrutering selectie       1.00      1.00      1.00        49
#                               manager services       1.00      1.00      1.00       286
#                           manager supply chain       1.00      1.00      1.00        87
#                      manager technical support       1.00      1.00      1.00        37
#                            manager televerkoop       0.00      0.00      0.00         2
#                   manager training development       1.00      1.00      1.00        61
#                  manager veiligheid gezondheid       1.00      1.00      1.00        88
#    manager verkoopadministratieorderverwerking       1.00      1.00      1.00        55
#                         manager voorraadbeheer       1.00      1.00      1.00        29
#                              marketing manager       1.00      1.00      1.00       139
#                           marketing specialist       1.00      1.00      1.00       135
#            medewerker postverwerkingarchivaris       1.00      1.00      1.00        33
#                            medewerker services       1.00      1.00      1.00        89
#                        medical affairs advisor       0.40      1.00      0.57         8
#                        medical science liaison       0.00      0.00      0.00         3
#                              medisch directeur       0.00      0.00      0.00         2
#                 mergers acquisition specialist       0.00      0.00      0.00         1
#                      milieucordinator niveau a       0.79      1.00      0.88        33
#                      milieucordinator niveau b       0.00      0.00      0.00         9
#                                 netwerkmanager       1.00      1.00      1.00        38
#                                 office manager       1.00      1.00      1.00       114
#                            onderhoudstechnicus       1.00      1.00      1.00       173
#                                ontwerptekenaar       1.00      0.74      0.85        88
#                     operations support manager       1.00      1.00      1.00        76
#                              paralegal officer       1.00      1.00      1.00        64
#                             payroll specialist       1.00      1.00      1.00       140
#                             personal assistant       1.00      1.00      1.00       248
#                              personeelsplanner       1.00      1.00      1.00        50
#                                  plant manager       1.00      1.00      1.00        40
#                                pricing manager       1.00      1.00      1.00        16
#                             pricing specialist       1.00      1.00      1.00        30
#                                procesingenieur       1.00      1.00      1.00       159
#                    process engineering manager       1.00      1.00      1.00        56
#                     process improvement expert       0.72      1.00      0.83       151
#                                product manager       1.00      1.00      1.00       209
#                                  product owner       1.00      1.00      1.00       130
#                                productadviseur       1.00      1.00      1.00       610
#                               productieplanner       1.00      1.00      1.00       156
#                                program manager       1.00      1.00      1.00       132
#                              project assistent       1.00      1.00      1.00        46
#                       project customer advisor       0.00      0.00      0.00        26
#                    project engineering manager       1.00      1.00      1.00       160
#                     project management officer       1.00      1.00      1.00        43
#                          projectingenieur bouw       1.00      1.00      1.00        57
#           projectingenieur project engineering       1.00      1.00      1.00       344
#                              projectleider bim       1.00      1.00      1.00        20
#                             projectleider bouw       0.73      1.00      0.84        69
#                        projectleider kwaliteit       1.00      1.00      1.00        70
#                             projectleider labo       1.00      1.00      1.00        34
#              projectleider process engineering       1.00      1.00      1.00        28
#              projectleider project engineering       1.00      1.00      1.00       171
#                           projectleidermanager       1.00      1.00      1.00       457
#                            projectmanager bouw       1.00      1.00      1.00        33
#                              projectmanager it       1.00      1.00      1.00       329
#                        projectmanagerleider rd       1.00      1.00      1.00        78
#                              projectmedewerker       1.00      1.00      1.00       221
#                       projectontwikkelaar bouw       0.00      0.00      0.00        15
#                                     psycholoog       0.00      0.00      0.00        12
#                       receptionistetelefoniste       1.00      1.00      1.00       116
#                            regio sales manager       1.00      1.00      1.00       106
#                              reporting officer       1.00      1.00      1.00        95
#                             research assistant       1.00      1.00      1.00        32
#                   research development manager       1.00      1.00      1.00        79
#                             research scientist       1.00      1.00      1.00        67
#                                 risico analist       1.00      1.00      1.00        90
#                                   risk manager       1.00      1.00      1.00        74
#                             ruimtelijk planner       1.00      1.00      1.00         7
#                                 sales engineer       1.00      1.00      1.00       103
#                                  sales manager       1.00      1.00      1.00       171
#                     sales promotormerchandiser       1.00      1.00      1.00        26
#                       sap specialistconsultant       1.00      1.00      1.00        47
#                                    schoonmaker       0.50      0.19      0.28        21
#                                   scrum master       1.00      1.00      1.00        39
#          search engine optimisation specialist       0.00      0.00      0.00         4
#                             security architect       0.00      0.00      0.00        11
#                            security consultant       0.65      1.00      0.78        20
#                               security manager       1.00      1.00      1.00        28
#                            security specialist       0.79      1.00      0.89        58
#                      senior research scientist       1.00      1.00      1.00        24
#                   software development manager       1.00      1.00      1.00        63
#                              software engineer       1.00      1.00      1.00       292
#                             solution architect       0.70      1.00      0.82       179
#               specialist advertising promotion       0.00      0.00      0.00        20
#               specialist compensation benefits       1.00      1.00      1.00        42
#                          specialist compliance       1.00      1.00      1.00        78
#                         specialist distributie       1.00      1.00      1.00        30
#          specialist marktanalysemarktonderzoek       1.00      1.00      1.00        43
#                     specialist pr communicatie       0.87      1.00      0.93       163
#                 specialist productontwikkeling       1.00      1.00      1.00        88
#                specialist rekrutering selectie       1.00      1.00      1.00       316
#                specialist training development       1.00      1.00      1.00       124
#                      specialist voorraadbeheer       1.00      1.00      1.00        75
#                          stabiliteitsingenieur       1.00      1.00      1.00         5
#                                 stafmedewerker       0.99      1.00      1.00       148
#                     support engineer 1ste lijn       1.00      1.00      1.00       107
#                      support engineer 2de lijn       0.64      1.00      0.78       135
#                         sustainability manager       1.00      1.00      1.00        28
#                           systeemadministrator       1.00      1.00      1.00       126
#                               systeemarchitect       1.00      1.00      1.00        98
#                               systeemingenieur       1.00      1.00      1.00       326
#                                    tax manager       1.00      1.00      1.00        24
#                    teamleader customer service       1.00      1.00      1.00       154
#                           teamleader logistiek       1.00      1.00      1.00       194
#                            teamleader services       1.00      1.00      1.00       249
#                   teamleader technical support       1.00      1.00      1.00        59
#                         teamleader televerkoop       0.92      1.00      0.96        12
#                            technical architect       1.00      1.00      1.00       101
#                              technical trainer       0.00      0.00      0.00        75
#                   technical writer engineering       1.00      1.00      1.00        63
#                     technical writer marketing       1.00      0.76      0.87        17
#                          technician teamleader       1.00      1.00      1.00         8
#              technisch administratief bediende       1.00      1.00      1.00        71
#                           technisch medewerker       1.00      1.00      1.00        53
#                                       tekenaar       0.74      1.00      0.85        67
#                               telecom engineer       0.00      0.00      0.00        10
#                                   televerkoper       1.00      1.00      1.00        20
#                        trade marketing manager       1.00      1.00      1.00        13
#                     trade marketing specialist       1.00      0.33      0.50         9
#                                      treasurer       1.00      1.00      1.00        26
#                               treasury manager       1.00      1.00      1.00        24
#                            vastgoed prospector       0.00      0.00      0.00        12
#          verantwoordelijke industrile relaties       0.00      0.00      0.00        11
#                       verpleegkundige bachelor       0.70      1.00      0.82        55
#                    verpleegkundige gegradueerd       0.00      0.00      0.00        24
#                                       vertaler       1.00      1.00      1.00        24
#                              vertegenwoordiger       1.00      1.00      1.00       191
#                              warehouse manager       1.00      1.00      1.00        76
#                                      webmaster       0.72      1.00      0.84        26
#                           wellbeing specialist       0.59      1.00      0.74        16
#                                werfleider bouw       1.00      1.00      1.00        73
#                               werkvoorbereider       1.00      1.00      1.00       128
#                      winkelbediendekassierster       1.00      1.00      1.00       992
#                       zorgcordinator thuiszorg       0.00      0.00      0.00         4
#                                    zorgkundige       0.88      1.00      0.93        14
#                                    zorgmanager       1.00      0.50      0.67         4
#
#                                       accuracy                           0.97     27668
#                                      macro avg       0.85      0.86      0.85     27668
#                                   weighted avg       0.96      0.97      0.96     27668

# %%
from datetime import datetime
import os

CSV_PATH = "feedback/title_feedback.csv"
TEXT = input("Paste job description: ").strip()
if not TEXT:
    raise SystemExit("No text provided.")
model.eval()
device = next(model.parameters()).device

enc = tokenizer(
    TEXT,
    truncation=True,
    padding=True,
    max_length=512,
    return_tensors="pt",).to(device)

with torch.no_grad():
    out = model(**enc)
    logits = out.logits

probs = torch.softmax(logits, dim=-1).squeeze(0).cpu()
pred_idx = int(torch.argmax(probs).item())


pred_title = label_encoder.inverse_transform([pred_idx])[0]

print(f"\nPredicted title: {pred_title}")


# HR feedback
ans = input("Accept prediction? [Y/N]: ").strip().lower()
accepted = (ans == "Y")

corrected_title = None
if not accepted:
    corrected_title = input("Enter the correct title: ").strip() or None

row = {
    "timestamp": datetime.utcnow().isoformat(),
    "pred_title": pred_title,
    "accepted": bool(accepted),
    "corrected_title": corrected_title,
    "job_description": TEXT,
}

df = pd.DataFrame([row])
if os.path.exists(CSV_PATH):
    df.to_csv(CSV_PATH, mode="a", header=False, index=False)
else:
    df.to_csv(CSV_PATH, index=False)

print(f"\nFeedback saved to {CSV_PATH}")
# Out:
# Paste job description:  data analyst with 3 years experience
# Predicted title: reporting officer
# Accept prediction? [Y/N]:  y
# Enter the correct title:  repoting officer
# Feedback saved to feedback/title_feedback.csv

# %%
save_dir = "models/title"  

trainer.save_model(save_dir)

tokenizer.save_pretrained(save_dir)

joblib.dump(label_encoder, f"{save_dir}/label_encoder.pkl")

print(f"Model, tokenizer, and label encoder saved to: {save_dir}/")
